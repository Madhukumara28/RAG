# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhukumara28/RAG/blob/RAG1/RAG_web_Philips_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain_community langchainhub chromadb langchain langchain-openai langchain-google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 33.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.3/84.3 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 60.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 kB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 7.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
import os
os.environ['OPENAI_API_KEY'] = userdata.get('openAIYtKey')

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(web_paths=["https://www.usa.philips.com/c-m-mo/philips-avent-baby-products"])

docs = loader.load()
print(docs)
# Out:
# [Document(metadata={'source': 'https://www.usa.philips.com/c-m-mo/philips-avent-baby-products', 'title': 'Baby Care Products, Accessories & Baby Essentials | Share the Care', 'description': '#ShareTheCare with Philips Avent baby products. Find\nthe baby accessories and newborn essentials new\nparents need like bottles, pacifiers, nipples and more.', 'language': 'en-us'}, page_content='                  Baby Care Products, Accessories & Baby Essentials | Share the Care                                                  Free shipping on orders over $25          2-5 business day delivery            Easy Returns              Sign up and save                                     Products     Main menu   Products       Personal care     Main menu   Personal care     Oral Healthcare    Personal care   Oral Healthcare       Oral healthcare homepage       Sonicare Top Picks       Electric Toothbrushes       Sonicare for Kids       Sonicare Replacement brush heads       Philips One by Sonicare   
# ...

# %%
pip install text_splitter
# Out:
# ERROR: Could not find a version that satisfies the requirement text_splitter (from versions: none)
# ERROR: No matching distribution found for text_splitter

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap = 200)
splits = text_splitter.split_documents(docs)

# %%
print(splits[0])
print(splits[1])
print(splits[2])
# Out:
# page_content='Baby Care Products, Accessories & Baby Essentials | Share the Care                                                  Free shipping on orders over $25          2-5 business day delivery            Easy Returns              Sign up and save                                     Products     Main menu   Products       Personal care     Main menu   Personal care     Oral Healthcare    Personal care   Oral Healthcare       Oral healthcare homepage       Sonicare Top Picks       Electric Toothbrushes       Sonicare for Kids       Sonicare Replacement brush heads       Philips One by Sonicare       Power Flosser       Teeth whitening       Learn more about oral health       Spare Parts          For Men    Personal care   For Men       Men's grooming homepage       Male Grooming Top Picks       Face shavers       Head Shavers       OneBlade - Trim, edge, & shave       Multigroomers       Body groomers       Beard Trimmers       OneBlade and Norelco Replacement blades       Spare' 
# ...

# %%
print(len(splits))
# Out:
# 20

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

vectorstore = Chroma.from_documents(documents=splits, embedding=OpenAIEmbeddings())

# %%
import os

if 'OPENAI_API_KEY' in os.environ:
    print('OPENAI_API_KEY is set.')
else:
    print('OPENAI_API_KEY is NOT set.')
# Out:
# OPENAI_API_KEY is set.

# %%
print(vectorstore._collection.count())
# Out:
# 19

# %%
print(vectorstore._collection.get())
# Out:
# {'ids': ['abfef00f-f758-4d9a-aefa-2e886fbff116', 'a7e69988-5475-454a-b346-eedccc626c69', 'e35f2b58-2162-4255-a7ea-dda4fc101e46', '6c6e92dd-aca3-4e14-9ac0-ff57023f17c0', 'f5025479-d05a-45dd-90ca-2083d982e1d2', '0d796683-1882-44ec-9e8f-efa565981dae', '3a931acb-0d8d-4ccd-b218-b05f99df4455', '60921f25-6c3c-4bec-850d-65f40cbba9f0', '05fcca39-12d8-4d2c-b958-0f8d830f3a87', '4d2a3633-c20f-48e8-9106-a96a52789c92', 'ff47da9f-e135-4192-8b3c-964fb5e859a0', '21458b74-b976-4aa9-800c-d1744414a164', 'eb485447-689d-46ff-92d7-5b6048b6097e', '647b16ba-321b-427c-8dc6-dbe0841e5268', '1db96744-384d-41a5-9620-31050320f71e', '459ce927-a399-4b17-a470-44c70edf74e7', '91f23fe1-cb1f-4b73-9a36-69ed84e01161', '5458c419-5da5-4e98-adc0-00dc49185628', '8c8d2af8-5af3-4128-9610-90717c817e88'], 'embeddings': None, 'documents': ["Baby Care Products, Accessories & Baby Essentials | Share the Care                                                  Free shipping on orders over $25          2-5 business day delivery          
# ...

# %%
print("\nCollection 1 - ", vectorstore._collection.get(ids=['28651d9a-ab51-41f8-ab83-e68285623c4e'], include=["embeddings", "documents"]))
print("\nCollection 2 - ", vectorstore._collection.get(ids=['054dee19-19ed-4574-bc51-511060fd707a'], include=["embeddings", "documents"]))
print("\nCollection 3 - ", vectorstore._collection.get(ids=['2fd71cb4-835a-43c5-b920-b7e1be51c450'], include=["embeddings", "documents"]))
# Out:
# Collection 1 -  {'ids': [], 'embeddings': array([], dtype=float64), 'documents': [], 'uris': None, 'included': ['embeddings', 'documents'], 'data': None, 'metadatas': None}
#
# Collection 2 -  {'ids': [], 'embeddings': array([], dtype=float64), 'documents': [], 'uris': None, 'included': ['embeddings', 'documents'], 'data': None, 'metadatas': None}
#
# Collection 3 -  {'ids': [], 'embeddings': array([], dtype=float64), 'documents': [], 'uris': None, 'included': ['embeddings', 'documents'], 'data': None, 'metadatas': None}

# %%
retriever = vectorstore.as_retriever()

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template("You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question}\nContext: {context}\nAnswer:")

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI()

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(docs):
  return "\n".join(doc.page_content for doc in docs)

# %%
rag_chain = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()}
             | prompt
             | llm
             | StrOutputParser())

# %%
rag_chain.invoke("Are Face shavers available? For how long?")
# Out:
# "Yes, face shavers are available. They have been mentioned as part of the men's grooming products lineup alongside other grooming tools. The exact length of time they have been available is not specified."

# %%
rag_chain.invoke("Are baby items available? Name the products")
# Out:
# 'Yes, baby items are available on the website. Some of the products offered include baby bottles, replacement nipples, gift sets, pacifiers, breast pumps & care, warmers & sterilizers, and baby monitors.'

# %%
from langchain_core.runnables import RunnableLambda

# %%
def print_prompt(prompt_text):
  print("Prompt - ", prompt_text)
  return prompt_text

# %%
rag_chain_with_print = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()}
             | prompt
             | RunnableLambda(print_prompt)
             | llm
             | StrOutputParser())

# %%
rag_chain_with_print.invoke("What all products available?")
# Out:
# Prompt -  messages=[HumanMessage(content="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: What all products available?\nContext: order                       support search icon           Search terms              What are you looking for?                 0   Shopping cart      There are currently no items in your shopping cart.     Checkout   Continue shopping                              Personal care      Household products      Mother & child care      Health      Lighting      Sound & vision      Automotive      Accessories       Promotions                                                                                    Anti-colic bottles for a calm, comfortable feed                     Shop Now                          Shop Now                              Anti-colic bottles for 
# ...

# %% [markdown]
# # Task
# Define the RAG prompt manually in cell `w861xJ0vCMPE` using `ChatPromptTemplate.from_template` to fix the `ImportError` and then confirm that the RAG chain can be successfully built and invoked.

# %% [markdown]
# ## Define RAG Prompt Manually
#
# ### Subtask:
# Modify cell `w861xJ0vCMPE` to define the RAG prompt using `ChatPromptTemplate.from_template` instead of `hub.pull`. This will bypass the `ImportError`.

# %% [markdown]
# **Reasoning**:
# The previous attempt to pull a prompt from `langchain.hub` resulted in an `ImportError`. To fix this, I will modify cell `w861xJ0vCMPE` to import `ChatPromptTemplate` and define the RAG prompt directly using `ChatPromptTemplate.from_template`, as instructed by the subtask.

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template("You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question}\nContext: {context}\nAnswer:")

# %% [markdown]
# **Reasoning**:
# The previous step defined the `prompt` variable correctly in a new cell. Now, I need to execute the cell that defines the `rag_chain` using this newly defined `prompt`. This will confirm that the `NameError` is resolved.

# %%
rag_chain = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()}
             | prompt
             | llm
             | StrOutputParser())

# %% [markdown]
# **Reasoning**:
# The previous step defined the `prompt` variable correctly in a new cell. Now, I need to execute the cell that defines the `rag_chain` using this newly defined `prompt`. This will confirm that the `NameError` is resolved.

# %%
rag_chain = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()}
             | prompt
             | llm
             | StrOutputParser())

# %% [markdown]
# **Reasoning**:
# Now that the `rag_chain` is successfully defined, I need to define the `rag_chain_with_print` as well, since it also uses the `prompt` variable and was previously blocked by the `NameError`. I will update and execute `cell_id: J4LDfcGMKzqJ`.

# %%
rag_chain_with_print = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()}
             | prompt
             | RunnableLambda(print_prompt)
             | llm
             | StrOutputParser())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4268331906.py in <cell line: 0>()
#       1 rag_chain_with_print = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()}
#       2              | prompt
# ----> 3              | RunnableLambda(print_prompt)
#       4              | llm
#       5              | StrOutputParser())
#
# NameError: name 'RunnableLambda' is not defined

# %% [markdown]
# **Reasoning**:
# The `NameError: name 'RunnableLambda' is not defined` indicates that the `RunnableLambda` class was not imported or its import statement was not executed. Although `langchain_core.runnables` was imported in `N1k9vBnqLduP`, its execution status was 'not yet executed'. To fix this, I will add the import statement for `RunnableLambda` directly into cell `b6300b8b` (which is a copy of `J4LDfcGMKzqJ` that caused the error) to ensure it is available when `rag_chain_with_print` is defined.

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

rag_chain_with_print = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()}
             | prompt
             | RunnableLambda(print_prompt)
             | llm
             | StrOutputParser())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1905435504.py in <cell line: 0>()
#       4 rag_chain_with_print = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()}
#       5              | prompt
# ----> 6              | RunnableLambda(print_prompt)
#       7              | llm
#       8              | StrOutputParser())
#
# NameError: name 'print_prompt' is not defined

# %% [markdown]
# **Reasoning**:
# The previous attempt to define `rag_chain_with_print` failed because `print_prompt` was not defined within the scope of the cell. To resolve this, I will move the `print_prompt` function definition into the same cell where `rag_chain_with_print` is being defined, ensuring its availability.

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

def print_prompt(prompt_text):
  print("Prompt - ", prompt_text)
  return prompt_text

rag_chain_with_print = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()})
             | prompt
             | RunnableLambda(print_prompt)
             | llm
             | StrOutputParser())
# Out:
#   File "/tmp/ipython-input-949228494.py", line 9
#     | prompt
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# **Reasoning**:
# The previous code block resulted in an `IndentationError` because of incorrect spacing in the chained operations for `rag_chain_with_print`. I will correct the indentation to ensure proper chaining.

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

def print_prompt(prompt_text):
  print("Prompt - ", prompt_text)
  return prompt_text

rag_chain_with_print = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()})
             .pipe(prompt)
             .pipe(RunnableLambda(print_prompt))
             .pipe(llm)
             .pipe(StrOutputParser())
# Out:
#   File "/tmp/ipython-input-1822739366.py", line 9
#     .pipe(prompt)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# **Reasoning**:
# The previous code block resulted in an `IndentationError` because of incorrect spacing in the chained operations for `rag_chain_with_print`. I will correct the indentation and ensure consistent use of the `|` operator for chaining.

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

def print_prompt(prompt_text):
  print("Prompt - ", prompt_text)
  return prompt_text

rag_chain_with_print = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()}
             | prompt
             | RunnableLambda(print_prompt)
             | llm
             | StrOutputParser())

# %% [markdown]
# **Reasoning**:
# The previous code block resulted in an `IndentationError` because of incorrect spacing in the chained operations for `rag_chain_with_print`. I will correct the indentation and ensure consistent use of the `|` operator for chaining.

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

def print_prompt(prompt_text):
  print("Prompt - ", prompt_text)
  return prompt_text

rag_chain_with_print = ({"context" : retriever | format_docs, "question" : RunnablePassthrough()}
             | prompt
             | RunnableLambda(print_prompt)
             | llm
             | StrOutputParser())

# %% [markdown]
# **Reasoning**:
# The previous code block successfully defined `rag_chain_with_print` without errors. To confirm that the RAG chain can be successfully built and invoked, as per the subtask, I will now invoke `rag_chain_with_print` with a sample question.

# %%
rag_chain_with_print.invoke("What all projects are covered in the course?")
# Out:
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x7a600884f8f0>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/google/auth/compute_engine/credentials.py", line 140, in _refresh_token
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.12/dist-packages/google/auth/compute_engine/credentials.py", line 107, in _retrieve_info
#     info = _metadata.get_service_account_info(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/google/auth/compute_engine/_metadata.py", line 342, in get_service_account_info
#     return get(request, path, params={"recursive": "true"})
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/google/auth/compute_engine/_metadata.py", line 267, in get
#     raise exceptions.TransportError(
# ...
